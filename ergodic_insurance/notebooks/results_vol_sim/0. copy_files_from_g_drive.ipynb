# %% [markdown]
# # Adjust this to copy files from G Drive to the USB-C Drive without errors

# %%
import shutil
import os
from pathlib import Path
import re

def sanitize_filename(filename):
    """Remove or replace invalid characters for Windows/USB drives"""
    # Replace problematic characters
    invalid_chars = r'[<>:"|?*]'
    filename = re.sub(invalid_chars, '_', filename)
    # Remove leading/trailing spaces and dots
    filename = filename.strip('. ')
    return filename

def copy_files_safe(source_dir, dest_dir, max_retries=3):
    """Copy files with error handling and retry logic"""
    source_path = Path(source_dir)
    dest_path = Path(dest_dir)
    
    # Create destination if it doesn't exist
    dest_path.mkdir(parents=True, exist_ok=True)
    
    copied = []
    failed = []
    skipped = []
    
    for item in source_path.rglob('*'):
        if item.is_file():
            try:
                # Calculate relative path
                rel_path = item.relative_to(source_path)
                
                # Sanitize each part of the path
                sanitized_parts = [sanitize_filename(part) for part in rel_path.parts]
                dest_file = dest_path / Path(*sanitized_parts)
                
                # Check if file already exists
                if dest_file.exists():
                    skipped.append(str(rel_path))
                    # print(f"⊘ Skipped (exists): {rel_path}")
                    continue
                
                # Create parent directories
                dest_file.parent.mkdir(parents=True, exist_ok=True)
                
                # Copy with retry
                for attempt in range(max_retries):
                    try:
                        shutil.copy2(item, dest_file)
                        copied.append(str(rel_path))
                        print(f"✓ Copied: {rel_path}")
                        break
                    except Exception as e:
                        if attempt == max_retries - 1:
                            raise
                        print(f"  Retry {attempt + 1} for {rel_path}")
                        
            except Exception as e:
                failed.append((str(item), str(e)))
                print(f"✗ Failed: {item} - {e}")
    
    print(f"\n{len(copied)} files copied successfully")
    print(f"{len(skipped)} files skipped (already exist)")
    if failed:
        print(f"{len(failed)} files failed:")
        for path, error in failed:
            print(f"  {path}: {error}")
    
    return copied, failed, skipped

### Small Model #####
# source = r"G:\My Drive\Colab Notebooks\results"  # Google Drive
# destination = r"D:\2026-01-29 Vol Small"  # USB drive

### Full Volatility Model #####
source = r"G:\My Drive\Colab Notebooks\results_vol_full"  # Google Drive
destination = r"D:\2026-01-31 Vol"  # USB drive

copy_files_safe(source, destination, max_retries=10)
# Out:
# ✓ Copied: Cap (25M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (233162) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl
# ✓ Copied: Cap (25M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (50115) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl
# ✓ Copied: Cap (25M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (31613) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl
# ✓ Copied: Cap (10M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (8522) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl
# ✓ Copied: Cap (25M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (11741) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl
# ✓ Copied: Cap (10M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (83572) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl
#
# 6 files copied successfully
# 52 files skipped (already exist)
# (['Cap (25M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (233162) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (25M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (50115) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (25M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (31613) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (8522) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (25M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (11741) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (83572) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl'],
#  [],
#  ['Cap (10M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (28302) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (3099) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (7365) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (2310) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (5105) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (4640) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (40157) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (25M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (14623) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (25M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (50115) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (9577) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (1798) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (66514) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (3378) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (3032) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (7064) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (2596) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (2157) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (9448) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (211139) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (7067) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (2403) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (4640) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (5105) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (2310) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (54215) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (53761) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (5370) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (1798) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (3099) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (66514) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (9577) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (28302) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (3378) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (7064) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (3032) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (8522) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (83572) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (7365) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (19018) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (2596) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (2157) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (5M) -    ATR (1.2) -    EBITABL (0.125) -    XS_Kurt (9448) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (211139) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (2403) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (7067) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (31865) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (14635) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (8331) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (40157) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (53761) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (54215) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl',
#   'Cap (10M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (5370) -    NOINS -    Vol (0.15) -    250K Sims -    50 Yrs.pkl'])
