# %% [markdown]
# # Adjust this to copy files from G Drive to the USB-C Drive without errors

# %% [markdown]
# ## Naive

# %%
import shutil
import os
from pathlib import Path
import re

def sanitize_filename(filename):
    """Remove or replace invalid characters for Windows/USB drives"""
    # Replace problematic characters
    invalid_chars = r'[<>:"|?*]'
    filename = re.sub(invalid_chars, '_', filename)
    # Remove leading/trailing spaces and dots
    filename = filename.strip('. ')
    return filename

def copy_files_safe(source_dir, dest_dir, max_retries=3):
    """Copy files with error handling and retry logic"""
    source_path = Path(source_dir)
    dest_path = Path(dest_dir)
    
    # Create destination if it doesn't exist
    dest_path.mkdir(parents=True, exist_ok=True)
    
    copied = []
    failed = []
    skipped = []
    
    for item in source_path.rglob('*'):
        if item.is_file():
            try:
                # Calculate relative path
                rel_path = item.relative_to(source_path)
                
                # Sanitize each part of the path
                sanitized_parts = [sanitize_filename(part) for part in rel_path.parts]
                dest_file = dest_path / Path(*sanitized_parts)
                
                # Check if file already exists
                if dest_file.exists():
                    skipped.append(str(rel_path))
                    # print(f"⊘ Skipped (exists): {rel_path}")
                    continue
                
                # Create parent directories
                dest_file.parent.mkdir(parents=True, exist_ok=True)
                
                # Copy with retry
                for attempt in range(max_retries):
                    try:
                        shutil.copy2(item, dest_file)
                        copied.append(str(rel_path))
                        print(f"✓ Copied: {rel_path}")
                        break
                    except Exception as e:
                        if attempt == max_retries - 1:
                            raise
                        print(f"  Retry {attempt + 1} for {rel_path}")
                        
            except Exception as e:
                failed.append((str(item), str(e)))
                print(f"✗ Failed: {item} - {e}")
    
    print(f"\n{len(copied)} files copied successfully")
    print(f"{len(skipped)} files skipped (already exist)")
    if failed:
        print(f"{len(failed)} files failed:")
        for path, error in failed:
            print(f"  {path}: {error}")
    
    return copied, failed, skipped

source = r"G:\My Drive\Colab Notebooks\results"  # Google Drive
destination = r"D:\Ergodicity Simulations\2025-10-15 Run - Hier Freq and X Shape"  # USB drive

# copy_files_safe(source, destination, max_retries=10)

# %% [markdown]
# ## More Optimized

# %%
import shutil
import os
from pathlib import Path
import re
import gc
import time
import threading

def sanitize_filename(filename):
    """Remove or replace invalid characters for Windows/USB drives"""
    invalid_chars = r'[<>:"|?*]'
    filename = re.sub(invalid_chars, '_', filename)
    filename = filename.strip('. ')
    return filename

def copy_with_timeout(src, dst, timeout=30):
    """Copy a file with a timeout to prevent hanging"""
    result = {'success': False, 'error': None}
    
    def copy_file():
        try:
            shutil.copy2(src, dst)
            result['success'] = True
        except Exception as e:
            result['error'] = e
    
    thread = threading.Thread(target=copy_file)
    thread.daemon = True
    thread.start()
    thread.join(timeout)
    
    if thread.is_alive():
        # Thread is still running - it hung
        result['error'] = TimeoutError(f"Copy operation timed out after {timeout} seconds")
        return result
    
    return result

def copy_files_safe_with_timeout(source_dir, dest_dir, max_retries=3, batch_size=1000, resume_from=0, copy_timeout=30):
    """Copy files with timeout handling to prevent hanging"""
    source_path = Path(source_dir)
    dest_path = Path(dest_dir)
    
    # Create destination if it doesn't exist
    dest_path.mkdir(parents=True, exist_ok=True)
    
    copied = []
    failed = []
    skipped = []
    processed = 0
    
    # Checkpoint file
    checkpoint_file = dest_path / "_copy_checkpoint.txt"
    
    print(f"Scanning source directory... (this may take a moment)")
    all_files = [f for f in source_path.rglob('*') if f.is_file()]
    total_files = len(all_files)
    print(f"Found {total_files} files to process")
    
    # Start from resume point if specified
    if resume_from > 0:
        print(f"Resuming from file {resume_from}")
        all_files = all_files[resume_from:]
    
    for idx, item in enumerate(all_files, start=resume_from):
        try:
            # Save checkpoint every 50 files
            if processed % 50 == 0:
                checkpoint_data = f"Index: {idx}\nProcessed: {processed}\nLast file: {item}\nTime: {time.strftime('%Y-%m-%d %H:%M:%S')}"
                checkpoint_file.write_text(checkpoint_data)
                print(f"Progress: {processed}/{total_files} files processed... [Checkpoint saved]")
            
            # Print current file being processed
            rel_path = item.relative_to(source_path)
            if processed % 10 == 0:
                print(f"  Processing: {rel_path}")
            
            # Check path length
            full_dest_path = dest_path / rel_path
            if len(str(full_dest_path)) > 250:
                print(f"⚠ Path too long, skipping: {rel_path}")
                failed.append((str(item), "Path exceeds Windows limit"))
                processed += 1
                continue
            
            # Sanitize path
            sanitized_parts = [sanitize_filename(part) for part in rel_path.parts]
            dest_file = dest_path / Path(*sanitized_parts)
            
            # Check if exists
            if dest_file.exists():
                skipped.append(str(rel_path))
                processed += 1
                continue
            
            # Create parent directories
            dest_file.parent.mkdir(parents=True, exist_ok=True)
            
            # Copy with timeout and retry
            copy_success = False
            for attempt in range(max_retries):
                try:
                    print(f"    Copying: {rel_path} (attempt {attempt + 1}/{max_retries})...")
                    result = copy_with_timeout(item, dest_file, timeout=copy_timeout)
                    
                    if result['success']:
                        copied.append(str(rel_path))
                        print(f"    ✓ Success: {rel_path}")
                        copy_success = True
                        break
                    else:
                        error = result['error']
                        if isinstance(error, TimeoutError):
                            print(f"    ⏱ Timeout on attempt {attempt + 1}: {rel_path}")
                            if attempt < max_retries - 1:
                                print(f"    Waiting 5 seconds before retry...")
                                time.sleep(5)
                        else:
                            raise error
                            
                except PermissionError as e:
                    print(f"⚠ Permission denied: {rel_path}, skipping")
                    failed.append((str(item), str(e)))
                    break
                except Exception as e:
                    if attempt == max_retries - 1:
                        print(f"    ✗ Failed after {max_retries} attempts: {e}")
                        failed.append((str(item), str(e)))
                    else:
                        print(f"    Retry {attempt + 1}/{max_retries} for {rel_path}: {e}")
                        time.sleep(2)
            
            if not copy_success and not any(str(item) in f[0] for f in failed):
                failed.append((str(item), "Copy timed out after all retries"))
            
            processed += 1
            
            # Periodic cleanup
            if processed % batch_size == 0:
                print(f"\n{'='*60}")
                print(f"BATCH CHECKPOINT at {processed} files")
                print(f"Copied: {len(copied)}, Skipped: {len(skipped)}, Failed: {len(failed)}")
                print(f"{'='*60}\n")
                gc.collect()
                
        except Exception as e:
            failed.append((str(item), str(e)))
            print(f"✗ Unexpected error: {item} - {e}")
            processed += 1
    
    # Final summary
    print("\n" + "="*60)
    print(f"COPY COMPLETE")
    print(f"{len(copied)} files copied successfully")
    print(f"{len(skipped)} files skipped (already exist)")
    print(f"{len(failed)} files failed")
    print("="*60)
    
    if failed:
        print(f"\nFailed files:")
        for path, error in failed[:20]:
            print(f"  {path}: {error}")
        if len(failed) > 20:
            print(f"  ... and {len(failed) - 20} more")
    
    # Save final report
    report_file = dest_path / "_copy_report.txt"
    with open(report_file, 'w') as f:
        f.write(f"Copy Report - {time.strftime('%Y-%m-%d %H:%M:%S')}\n")
        f.write(f"Total files: {total_files}\n")
        f.write(f"Copied: {len(copied)}\n")
        f.write(f"Skipped: {len(skipped)}\n")
        f.write(f"Failed: {len(failed)}\n\n")
        if failed:
            f.write("Failed files:\n")
            for path, error in failed:
                f.write(f"  {path}: {error}\n")
    
    return copied, failed, skipped

# Run the copy
source = r"G:\My Drive\Colab Notebooks\results"
destination = r"D:\2025-10-15 Run - Hier Freq and X Shape"

# Start fresh or resume from checkpoint
# Check _copy_checkpoint.txt to see where it stopped
copied, failed, skipped = copy_files_safe_with_timeout(
    source, 
    destination, 
    max_retries=10, 
    batch_size=1000,
    resume_from=0,  # Change this to resume from a specific index
    copy_timeout=30  # 30 second timeout per file
)
# Out:
# Scanning source directory... (this may take a moment)
# Found 49126 files to process
# Progress: 0/49126 files processed... [Checkpoint saved]
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (0.480) - X_Th_%le (0.0005) - X_Shape (0.562) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (1.134) - X_Th_%le (0.0005) - X_Shape (0.457) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (0.936) - X_Th_%le (0.0005) - X_Shape (0.353) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (0.726) - X_Th_%le (0.0005) - X_Shape (0.381) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (0.509) - X_Th_%le (0.0005) - X_Shape (0.271) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
# Progress: 50/49126 files processed... [Checkpoint saved]
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (0.896) - X_Th_%le (0.0005) - X_Shape (0.610) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (0.972) - X_Th_%le (0.0005) - X_Shape (0.344) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (1.525) - X_Th_%le (0.0005) - X_Shape (0.391) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (1.220) - X_Th_%le (0.0005) - X_Shape (0.372) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (0.733) - X_Th_%le (0.0005) - X_Shape (0.405) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
# Progress: 100/49126 files processed... [Checkpoint saved]
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (0.575) - X_Th_%le (0.0005) - X_Shape (0.460) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (1.043) - X_Th_%le (0.0005) - X_Shape (0.515) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (1.754) - X_Th_%le (0.0005) - X_Shape (0.508) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (0.770) - X_Th_%le (0.0005) - X_Shape (1.020) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (0.986) - X_Th_%le (0.0005) - X_Shape (0.632) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
# Progress: 150/49126 files processed... [Checkpoint saved]
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (1.274) - X_Th_%le (0.0005) - X_Shape (0.273) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (1.266) - X_Th_%le (0.0005) - X_Shape (0.362) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (0.394) - X_Th_%le (0.0005) - X_Shape (0.334) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (1.459) - X_Th_%le (0.0005) - X_Shape (0.382) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (1.012) - X_Th_%le (0.0005) - X_Shape (0.425) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
# Progress: 200/49126 files processed... [Checkpoint saved]
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (1.217) - X_Th_%le (0.0005) - X_Shape (0.474) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (0.704) - X_Th_%le (0.0005) - X_Shape (0.832) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (1.234) - X_Th_%le (0.0005) - X_Shape (0.459) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (0.819) - X_Th_%le (0.0005) - X_Shape (0.921) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (0.764) - X_Th_%le (0.0005) - X_Shape (0.450) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
# Progress: 250/49126 files processed... [Checkpoint saved]
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (0.931) - X_Th_%le (0.0005) - X_Shape (0.818) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (1.657) - X_Th_%le (0.0005) - X_Shape (0.655) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (0.927) - X_Th_%le (0.0005) - X_Shape (0.383) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (1.096) - X_Th_%le (0.0005) - X_Shape (1.029) - X_Scale (1.0) - 10K Sims - 25 Yrs.pkl
#   Processing: Cap (75M) - Ded (100K) - LR (0.6) - Pol_Lim (75M) - F_Scale (0
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.6877768703877768) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.5382743501518765) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.6597871065685478) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 48250/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.6285924674360346) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.3094028187816537) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.4171538196177774) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.5722927774939109) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.41024263106869224) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 48300/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.2918954455481385) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.6807642001610179) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.45414473977205955) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.5775162626306618) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.6379307045971332) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 48350/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (1.0920707293932057) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.905873274619848) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.38286721582637745) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.48944294827594487) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.3153154875963836) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 48400/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.4551330405839438) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.3666056434835236) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.2937903334543104) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.5129163661171111) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.5735358900694428) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 48450/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.7049753885015527) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.4389637833965586) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.2780005107310275) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.574838706841313) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.2891428307643153) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 48500/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.47172967771270796) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.5276752772750894) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.7409224400866758) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.28772766575202063) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.3037144659837849) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 48550/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.6038388020198303) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.4426019283558955) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.50333205968496) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.7807383149267321) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.7630134471874095) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 48600/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.4836611679315956) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.739138604118057) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.5107419553261994) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.9101213971653754) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.32635350975789595) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 48650/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.6590117012498905) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.5263227570703588) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.7313256715406894) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.86691518195768) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.9178117609845823) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 48700/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.3612322634450973) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.8361769725429202) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.3126267150198003) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.5040546532347361) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.581537062120026) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 48750/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.35069551822704603) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.6002557874139021) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.3049492259719726) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (1.2760837237420841) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.7671584533333959) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 48800/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.48203202038215487) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.36542148044936323) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.5649193224518337) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.6908026011615446) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.49589117934004534) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 48850/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.5134336189038378) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.5512986399302017) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.40312186879786155) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.7788007338011893) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (1.1766263149997551) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 48900/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.5325515028993599) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.6189968995857474) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.5291733398246088) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.5877795353308612) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.4067420193927079) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 48950/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.6749177038217888) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.4131363071829075) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.3701113286884835) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.8866760733921285) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.8322778658315934) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 49000/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.5239480172859703) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.6763177753609487) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.4674142274581685) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.6079323143985573) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.43848601146577154) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 49050/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.47939337297766677) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.6703109559289911) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.4275239730816765) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.7944055370335037) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.3170731806685637) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
# Progress: 49100/49126 files processed... [Checkpoint saved]
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.2517185330878698) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.502821754670359) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#   Processing: 1K\Cap (75M) - Ded (1000K) - LR (0.6) - Pol_Lim (1000M) - X_Th_%le (0.0005) - X_Shape (0.4421505721329118) - X_Scale (1.0) - 1K Sims - 25 Yrs.pkl
#
# ============================================================
# COPY COMPLETE
# 835 files copied successfully
# 48291 files skipped (already exist)
# 0 files failed
# ============================================================
