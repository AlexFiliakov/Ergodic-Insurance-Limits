# %% [markdown]
# # Adjust this to copy files from G Drive to the USB-C Drive without errors

# %%
import shutil
import os
from pathlib import Path
import re

def sanitize_filename(filename):
    """Remove or replace invalid characters for Windows/USB drives"""
    # Replace problematic characters
    invalid_chars = r'[<>:"|?*]'
    filename = re.sub(invalid_chars, '_', filename)
    # Remove leading/trailing spaces and dots
    filename = filename.strip('. ')
    return filename

def copy_files_safe(source_dir, dest_dir, max_retries=3):
    """Copy files with error handling and retry logic"""
    source_path = Path(source_dir)
    dest_path = Path(dest_dir)
    
    # Create destination if it doesn't exist
    dest_path.mkdir(parents=True, exist_ok=True)
    
    copied = []
    failed = []
    skipped = []
    
    for item in source_path.rglob('*'):
        if item.is_file():
            try:
                # Calculate relative path
                rel_path = item.relative_to(source_path)
                
                # Sanitize each part of the path
                sanitized_parts = [sanitize_filename(part) for part in rel_path.parts]
                dest_file = dest_path / Path(*sanitized_parts)
                
                # Check if file already exists
                if dest_file.exists():
                    skipped.append(str(rel_path))
                    # print(f"⊘ Skipped (exists): {rel_path}")
                    continue
                
                # Create parent directories
                dest_file.parent.mkdir(parents=True, exist_ok=True)
                
                # Copy with retry
                for attempt in range(max_retries):
                    try:
                        shutil.copy2(item, dest_file)
                        copied.append(str(rel_path))
                        print(f"✓ Copied: {rel_path}")
                        break
                    except Exception as e:
                        if attempt == max_retries - 1:
                            raise
                        print(f"  Retry {attempt + 1} for {rel_path}")
                        
            except Exception as e:
                failed.append((str(item), str(e)))
                print(f"✗ Failed: {item} - {e}")
    
    print(f"\n{len(copied)} files copied successfully")
    print(f"{len(skipped)} files skipped (already exist)")
    if failed:
        print(f"{len(failed)} files failed:")
        for path, error in failed:
            print(f"  {path}: {error}")
    
    return copied, failed, skipped

### Small Model #####
# source = r"G:\My Drive\Colab Notebooks\results"  # Google Drive
# destination = r"D:\2026-01-29 Vol Small"  # USB drive

### Full Volatility Model #####
source = r"G:\My Drive\Colab Notebooks\results_vol_full"  # Google Drive
destination = r"D:\2026-01-30 Vol"  # USB drive

copy_files_safe(source, destination, max_retries=10)
# Out:
# 0 files copied successfully
# 1350 files skipped (already exist)
# ([],
#  [],
#  ['Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (1424) -    Ded (0K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (4180) -    Ded (100K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (3542) -    Ded (50K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (2648) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (13001) -    Ded (0K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (1837) -    Ded (500K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (1168) -    Ded (500K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (180324) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (1398) -    Ded (250K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (4752) -    Ded (50K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (4906) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (4239) -    Ded (250K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (2741) -    Ded (500K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (2697) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (2107) -    Ded (50K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (7440) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (1971) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (17083) -    Ded (500K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (8740) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (35359) -    Ded (100K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (1084) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (4223) -    Ded (250K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (102139) -    Ded (100K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (4251) -    Ded (0K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (10659) -    Ded (100K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (5295) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (2995) -    Ded (250K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (11493) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (12348) -    Ded (500K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (7973) -    Ded (50K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (2804) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (4227) -    Ded (50K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (2362) -    Ded (250K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (1435) -    Ded (100K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (33651) -    Ded (50K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (5971) -    Ded (0K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (7210) -    Ded (0K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (2405) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (12562) -    Ded (250K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (9187) -    Ded (50K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (3790) -    Ded (50K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (3302) -    Ded (100K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (2286) -    Ded (50K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (1622) -    Ded (0K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (1424) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (3542) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (4180) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (2648) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (2107) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (180324) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (2741) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (4906) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (2362) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (13001) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (4239) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (17083) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (102139) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (1084) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (2697) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (1168) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (11493) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (12348) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (2995) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (1398) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (7440) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (1971) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (1837) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (8740) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (12562) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (2804) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (33651) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (5971) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (7210) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (3790) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (1622) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (10659) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (2405) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (4752) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (7973) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (4223) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (2286) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (5295) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (1435) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (4251) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (9187) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (3302) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (35359) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (4227) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (1376) -    Ded (500K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (3624) -    Ded (0K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (9046) -    Ded (0K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (1683) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (3709) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (1799) -    Ded (50K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (1837) -    Ded (50K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (1599) -    Ded (0K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (1051) -    Ded (100K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (2111) -    Ded (50K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (5282) -    Ded (250K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (1523) -    Ded (50K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (17033) -    Ded (250K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (2274) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (2724) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (7076) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (1865) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (2148) -    Ded (50K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (13442) -    Ded (250K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (41010) -    Ded (500K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (11707) -    Ded (100K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (3265) -    Ded (250K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (2361) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (12831) -    Ded (500K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (5982) -    Ded (500K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (1781) -    Ded (250K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (5709) -    Ded (100K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (27338) -    Ded (50K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (1836) -    Ded (50K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (11075) -    Ded (0K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (1413) -    Ded (250K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (3633) -    Ded (0K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (5271) -    Ded (100K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (1491) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (1979) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (37083) -    Ded (50K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (72910) -    Ded (0K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (3494) -    Ded (50K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (2158) -    Ded (100K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (1178) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (4080) -    Ded (100K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (2191) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (53090) -    Ded (500K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (2624) -    Ded (500K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (3624) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (1376) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (3709) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (9046) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (1683) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (1523) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (1799) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (1051) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (1599) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (2624) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (17033) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (2111) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (1837) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (7076) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (2274) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (5282) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (1491) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (1979) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (5982) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (53090) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (1865) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (2191) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (3633) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (2724) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (1836) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (5271) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (41010) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (3265) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (1413) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (12831) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (2148) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (72910) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (2361) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (1178) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (3494) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (2158) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (4080) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (11075) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (1781) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (11707) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (13442) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (27338) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (37083) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (5709) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (2340) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (5962) -    Ded (500K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (3556) -    Ded (0K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (2776) -    Ded (50K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (7878) -    Ded (100K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (3001) -    Ded (250K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (4751) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (87472) -    Ded (50K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (4282) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (4614) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (6744) -    Ded (500K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (4217) -    Ded (0K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (2164) -    Ded (50K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (4317) -    Ded (0K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (1210) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (21560) -    Ded (100K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (1565) -    Ded (50K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (1403) -    Ded (50K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (5440) -    Ded (50K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (11312) -    Ded (100K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (8213) -    Ded (250K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (5352) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (19122) -    Ded (250K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (4498) -    Ded (500K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (3174) -    Ded (500K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (3388) -    Ded (50K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (2694) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (1817) -    Ded (100K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (967) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (4385) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (293367) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (2661) -    Ded (250K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (27654) -    Ded (250K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (6391) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (16184) -    Ded (100K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (13172) -    Ded (50K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (4444) -    Ded (250K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (4744) -    Ded (500K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (3599) -    Ded (50K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (13613) -    Ded (0K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (2000) -    Ded (0K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (4816) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (1856) -    Ded (100K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (3609) -    Ded (0K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (5962) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (0.9) -    EBITABL (0.15) -    XS_Kurt (2340) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (3556) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (2776) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (7878) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (4751) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (4614) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (4317) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (2164) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (1210) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (6744) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (5440) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (3001) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (87472) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (1565) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (11312) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (4282) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (8213) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (4217) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (2694) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (3174) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (293367) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (3388) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (21560) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (1817) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (5352) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (16184) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (19122) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (2661) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.1) -    XS_Kurt (4498) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (4444) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (1403) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (967) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (27654) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (6391) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (2000) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (4385) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (3599) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (13172) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (13613) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (4816) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (3609) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.125) -    XS_Kurt (4744) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (1856) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (15554) -    Ded (500K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (1640) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (21759) -    Ded (500K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (3297) -    Ded (0K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (2812) -    Ded (0K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (5372) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (2371) -    Ded (0K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (4719) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (6706) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (15339) -    Ded (500K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (4206) -    Ded (100K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (5176) -    Ded (250K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (1370) -    Ded (500K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (3491) -    Ded (0K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (2602) -    Ded (100K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (4512) -    Ded (50K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (24197) -    Ded (50K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (2642) -    Ded (50K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (8887) -    Ded (50K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (4430) -    Ded (250K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (7460) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (2634) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (10438) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (8733) -    Ded (100K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (2094) -    Ded (100K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (282430) -    Ded (50K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (8972) -    Ded (500K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (3742) -    Ded (250K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (8737) -    Ded (50K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (2434) -    Ded (0K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (10307) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (8225) -    Ded (100K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (1690) -    Ded (50K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (7880) -    Ded (0K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (1447) -    Ded (50K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (1395) -    Ded (500K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (8673) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (10635) -    Ded (250K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (34302) -    Ded (50K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (1073) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (20945) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (4937) -    Ded (100K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (3502) -    Ded (250K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (319387) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (15554) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (1640) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.0) -    EBITABL (0.15) -    XS_Kurt (21759) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (3491) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (15339) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (3297) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (7460) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (1370) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (24197) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (4719) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (8887) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (2812) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (2634) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (2371) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (10438) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (5176) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (6706) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (2602) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (4430) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (4206) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (2642) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (8225) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (3742) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (5372) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (8737) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (7880) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.1) -    XS_Kurt (10307) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (1395) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (1073) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (1447) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (8733) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (8673) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (4512) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (282430) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (2434) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (10635) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (8972) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (1690) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.125) -    XS_Kurt (34302) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (2094) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (319387) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (3502) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (5M) -    ATR (1.1) -    EBITABL (0.15) -    XS_Kurt (20945) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
# ...
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (24532) -    Ded (0K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.15) -    XS_Kurt (9510) -    Ded (250K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.15) -    XS_Kurt (3661) -    Ded (100K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.15) -    XS_Kurt (4072) -    Ded (250K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (47629) -    Ded (50K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (4418) -    Ded (100K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (52843) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (10943) -    Ded (0K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.15) -    XS_Kurt (171781) -    Ded (500K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (5097) -    Ded (50K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (2603) -    Ded (100K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (33570) -    Ded (250K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (73753) -    Ded (50K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (4132) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (3047) -    Ded (250K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.15) -    XS_Kurt (9574) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (68648) -    Ded (500K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (14046) -    Ded (500K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (3758) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (3956) -    Ded (0K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (61811) -    Ded (50K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (2435215) -    Ded (0K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (60525) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (113083) -    Ded (50K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (10582) -    Ded (50K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (8565) -    Ded (100K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (4824) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (26676) -    Ded (100K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (5236) -    Ded (250K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (6022) -    Ded (250K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (3246) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (8678) -    Ded (500K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (8316) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (5808) -    Ded (500K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (23404) -    Ded (0K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (6781) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (42771) -    Ded (0K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (4160) -    Ded (50K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (17511) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.15) -    XS_Kurt (3703) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.15) -    XS_Kurt (11433) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.15) -    XS_Kurt (9574) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.15) -    XS_Kurt (39090) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.15) -    XS_Kurt (86482) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.15) -    XS_Kurt (3661) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.15) -    XS_Kurt (4072) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.15) -    XS_Kurt (9510) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (24532) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.15) -    XS_Kurt (14269) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (4418) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (10M) -    ATR (1.2) -    EBITABL (0.15) -    XS_Kurt (171781) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (47629) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (33570) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (10943) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (52843) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (2603) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (4132) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (73753) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (3047) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (14046) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (3758) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (68648) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.1) -    XS_Kurt (5097) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (3956) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (61811) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (2435215) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (60525) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (113083) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (10582) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (4824) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (8565) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (3246) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (5236) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (26676) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (6022) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (8678) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (8316) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (23404) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.125) -    XS_Kurt (5808) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (6781) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (4160) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (42771) -    NOINS -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (13328) -    Ded (0K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (3808) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (35963) -    Ded (0K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (11131) -    Ded (50K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (367156) -    Ded (100K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (561417) -    Ded (50K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (1127976) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (7054) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (5452) -    Ded (50K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (13752) -    Ded (100K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (3374) -    Ded (500K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (3916) -    Ded (50K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (13096) -    Ded (250K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (4846) -    Ded (250K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (12308) -    Ded (250K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (88676) -    Ded (100K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (19736) -    Ded (100K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (19396) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.8) -    EBITABL (0.15) -    XS_Kurt (9059) -    Ded (500K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (12632) -    Ded (50K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (68038) -    Ded (500K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (4789) -    Ded (100K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (10893) -    Ded (250K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (20101) -    Ded (250K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (5127) -    Ded (500K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.1) -    XS_Kurt (18411) -    Ded (500K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (5223) -    Ded (0K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (152375) -    Ded (0K) -    LR (0.8) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (111668) -    Ded (0K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (15953) -    Ded (50K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (12656) -    Ded (50K) -    LR (0.7) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   'Cap (25M) -    ATR (0.9) -    EBITABL (0.125) -    XS_Kurt (17105) -    Ded (100K) -    LR (0.6) -    Vol (0.15) -    100K Sims -    25 Yrs.pkl',
#   ...])
