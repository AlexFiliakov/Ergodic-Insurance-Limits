# %% [markdown]
# # Adjust this to copy files from G Drive to the USB-C Drive without errors

# %%
import shutil
import os
from pathlib import Path
import re

def sanitize_filename(filename):
    """Remove or replace invalid characters for Windows/USB drives"""
    # Replace problematic characters
    invalid_chars = r'[<>:"|?*]'
    filename = re.sub(invalid_chars, '_', filename)
    # Remove leading/trailing spaces and dots
    filename = filename.strip('. ')
    return filename

def copy_files_safe(source_dir, dest_dir, max_retries=3):
    """Copy files with error handling and retry logic"""
    source_path = Path(source_dir)
    dest_path = Path(dest_dir)
    
    # Create destination if it doesn't exist
    dest_path.mkdir(parents=True, exist_ok=True)
    
    copied = []
    failed = []
    skipped = []
    
    for item in source_path.rglob('*'):
        if item.is_file():
            try:
                # Calculate relative path
                rel_path = item.relative_to(source_path)
                
                # Sanitize each part of the path
                sanitized_parts = [sanitize_filename(part) for part in rel_path.parts]
                dest_file = dest_path / Path(*sanitized_parts)
                
                # Check if file already exists
                if dest_file.exists():
                    skipped.append(str(rel_path))
                    # print(f"⊘ Skipped (exists): {rel_path}")
                    continue
                
                # Create parent directories
                dest_file.parent.mkdir(parents=True, exist_ok=True)
                
                # Copy with retry
                for attempt in range(max_retries):
                    try:
                        shutil.copy2(item, dest_file)
                        copied.append(str(rel_path))
                        print(f"✓ Copied: {rel_path}")
                        break
                    except Exception as e:
                        if attempt == max_retries - 1:
                            raise
                        print(f"  Retry {attempt + 1} for {rel_path}")
                        
            except Exception as e:
                failed.append((str(item), str(e)))
                print(f"✗ Failed: {item} - {e}")
    
    print(f"\n{len(copied)} files copied successfully")
    print(f"{len(skipped)} files skipped (already exist)")
    if failed:
        print(f"{len(failed)} files failed:")
        for path, error in failed:
            print(f"  {path}: {error}")
    
    return copied, failed, skipped

source = r"G:\My Drive\Colab Notebooks\results"  # Google Drive
destination = r"D:\Ergodicity Simulations\2025-10-10 Run - L Tail and Lim - production 1"  # USB drive

copy_files_safe(source, destination, max_retries=10)
# Out:
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (10M) - X_Th_%le (0.0001) - X_Shape (0.6) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (75M) - X_Th_%le (0.0005) - X_Shape (1.0) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (10M) - X_Th_%le (0.0005) - X_Shape (0.6) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (25M) - X_Th_%le (0.0005) - X_Shape (0.8) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
#   Retry 1 for Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (50M) - X_Th_%le (0.0005) - X_Shape (0.6) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (50M) - X_Th_%le (0.0005) - X_Shape (0.6) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (10M) - X_Th_%le (0.0005) - X_Shape (0.8) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (10M) - X_Th_%le (0.0005) - X_Shape (0.5) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (75M) - X_Th_%le (0.0001) - X_Shape (0.6) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (50M) - X_Th_%le (0.0005) - X_Shape (0.8) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (10M) - X_Th_%le (0.0001) - X_Shape (0.5) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
#   Retry 1 for Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (50M) - X_Th_%le (0.0001) - X_Shape (0.7) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
#   Retry 2 for Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (50M) - X_Th_%le (0.0001) - X_Shape (0.7) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (50M) - X_Th_%le (0.0001) - X_Shape (0.7) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
#   Retry 1 for Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (25M) - X_Th_%le (0.0005) - X_Shape (1.0) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (25M) - X_Th_%le (0.0005) - X_Shape (1.0) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (75M) - X_Th_%le (0.0005) - X_Shape (0.5) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (10M) - X_Th_%le (0.0001) - X_Shape (1.0) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (25M) - X_Th_%le (0.0005) - X_Shape (0.7) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (10M) - X_Th_%le (0.0005) - X_Shape (0.7) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
#   Retry 1 for Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (75M) - X_Th_%le (0.0005) - X_Shape (0.8) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
#   Retry 2 for Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (75M) - X_Th_%le (0.0005) - X_Shape (0.8) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (75M) - X_Th_%le (0.0005) - X_Shape (0.8) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (25M) - X_Th_%le (0.0005) - X_Shape (0.5) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
#   Retry 1 for Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (50M) - X_Th_%le (0.0001) - X_Shape (1.0) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (50M) - X_Th_%le (0.0001) - X_Shape (1.0) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (50M) - X_Th_%le (0.0001) - X_Shape (0.8) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
#   Retry 1 for Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (50M) - X_Th_%le (0.0005) - X_Shape (0.7) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (50M) - X_Th_%le (0.0005) - X_Shape (0.7) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (25M) - X_Th_%le (0.0005) - X_Shape (0.6) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (10M) - X_Th_%le (0.0001) - X_Shape (0.8) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (25M) - X_Th_%le (0.0001) - X_Shape (1.0) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (75M) - X_Th_%le (0.0005) - X_Shape (0.7) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (25M) - X_Th_%le (0.0001) - X_Shape (0.9) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (25M) - X_Th_%le (0.0001) - X_Shape (0.5) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (10M) - X_Th_%le (0.0001) - X_Shape (0.9) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (75M) - X_Th_%le (0.0005) - X_Shape (0.6) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
# ✓ Copied: Cap (10M) - Ded (250K) - LR (0.6) - Pol_Lim (10M) - X_Th_%le (0.0001) - X_Shape (0.7) - X_Scale (1.0) - 250K Sims - 50 Yrs.pkl
